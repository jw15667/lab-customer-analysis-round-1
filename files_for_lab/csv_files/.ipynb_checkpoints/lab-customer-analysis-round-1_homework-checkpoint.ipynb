# %%
import pandas as pd  # explain keywords are highlighted in green, other strings in red, etc.
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
file1.reindex(sorted(file1.columns), axis=1)
# Out:
#      Customer Customer Lifetime Value             Education GENDER   Income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 4003      NaN                     NaN                   NaN    NaN      NaN
# 4004      NaN                     NaN                   NaN    NaN      NaN
# 4005      NaN                     NaN                   NaN    NaN      NaN
# 4006      NaN                     NaN                   NaN    NaN      NaN
# 4007      NaN                     NaN                   NaN    NaN      NaN
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 4003                   NaN                       NaN             NaN
# 4004                   NaN                       NaN             NaN
# 4005                   NaN                       NaN             NaN
# 4006                   NaN                       NaN             NaN
# 4007                   NaN                       NaN             NaN
#
#               ST  Total Claim Amount  Vehicle Class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 4003         NaN                 NaN            NaN
# 4004         NaN                 NaN            NaN
# 4005         NaN                 NaN            NaN
# 4006         NaN                 NaN            NaN
# 4007         NaN                 NaN            NaN
#
# [4008 rows x 11 columns]

# %%
file2.reindex(sorted(file2.columns), axis=1)
# Out:
#     Customer Customer Lifetime Value Education GENDER  Income  \
# 0    GS98873              323912.47%  Bachelor      F   16061
# 1    CW49887              462680.11%    Master      F   79487
# 2    MY31220              899704.02%   College      F   54230
# 3    UH35128             2580706.30%   College      F   71210
# 4    WH52799              380812.21%   College      F   94903
# ..       ...                     ...       ...    ...     ...
# 991  HV85198              847141.75%    Master      M   63513
# 992  BS91566              543121.91%   College      F   58161
# 993  IL40123              568964.41%   College      F   83640
# 994  MY32149              368672.38%    Master      F       0
# 995  SA91515              399258.39%  Bachelor      M       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# 2                     112                    1/0/00   Personal Auto
# 3                     214                    1/1/00   Personal Auto
# 4                      94                    1/0/00  Corporate Auto
# ..                    ...                       ...             ...
# 991                    70                    1/0/00   Personal Auto
# 992                    68                    1/0/00  Corporate Auto
# 993                    70                    1/0/00  Corporate Auto
# 994                    96                    1/0/00   Personal Auto
# 995                   111                    1/0/00   Personal Auto
#
#              ST  Total Claim Amount  Vehicle Class
# 0       Arizona          633.600000  Four-Door Car
# 1    California          547.200000            SUV
# 2    California          537.600000   Two-Door Car
# 3        Oregon         1027.200000     Luxury Car
# 4       Arizona          451.200000   Two-Door Car
# ..          ...                 ...            ...
# 991     Arizona          185.667213  Four-Door Car
# 992     Arizona          140.747286  Four-Door Car
# 993      Nevada          471.050488   Two-Door Car
# 994  California           28.460568   Two-Door Car
# 995  California          700.349052            SUV
#
# [996 rows x 11 columns]

# %%
file3.reindex(sorted(file3.columns), axis=1)
# Out:
#      Customer  Customer Lifetime Value             Education Gender  Income  \
# 0     SA25987              3479.137523  High School or Below      M       0
# 1     TB86706              2502.637401                Master      M       0
# 2     ZL73902              3265.156348              Bachelor      F   25820
# 3     KX23516              4455.843406  High School or Below      F       0
# 4     FN77294              7704.958480  High School or Below      M   30366
# ...       ...                      ...                   ...    ...     ...
# 7065  LA72316             23405.987980              Bachelor      M   71941
# 7066  PK87824              3096.511217               College      F   21604
# 7067  TD14365              8163.890428              Bachelor      M       0
# 7068  UP19263              7524.442436               College      M   21941
# 7069  Y167826              2611.836866               College      M       0
#
#       Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                      104                          0   Personal Auto
# 1                       66                          0   Personal Auto
# 2                       82                          0   Personal Auto
# 3                      121                          0   Personal Auto
# 4                      101                          2   Personal Auto
# ...                    ...                        ...             ...
# 7065                    73                          0   Personal Auto
# 7066                    79                          0  Corporate Auto
# 7067                    85                          3  Corporate Auto
# 7068                    96                          0   Personal Auto
# 7069                    77                          0  Corporate Auto
#
#            State  Total Claim Amount  Vehicle Class
# 0     Washington          499.200000   Two-Door Car
# 1        Arizona            3.468912   Two-Door Car
# 2         Nevada          393.600000  Four-Door Car
# 3     California          699.615192            SUV
# 4     California          484.800000            SUV
# ...          ...                 ...            ...
# 7065  California          198.234764  Four-Door Car
# 7066  California          379.200000  Four-Door Car
# 7067  California          790.784983  Four-Door Car
# 7068  California          691.200000  Four-Door Car
# 7069  California          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
column_titles = []
for i in range(len(file1.columns)):
    column_titles.append(file1.columns[i].lower())
file1.columns = column_titles
file2.columns = column_titles
file3.columns = column_titles

# %%
file3.head()
# Out:
#   customer          st       gender             education  \
# 0  SA25987  Washington  3479.137523  High School or Below
# 1  TB86706     Arizona  2502.637401                Master
# 2  ZL73902      Nevada  3265.156348              Bachelor
# 3  KX23516  California  4455.843406  High School or Below
# 4  FN77294  California  7704.958480  High School or Below
#
#   customer lifetime value  income  monthly premium auto  \
# 0                       M       0                   104
# 1                       M       0                    66
# 2                       F   25820                    82
# 3                       F       0                   121
# 4                       M   30366                   101
#
#    number of open complaints    policy type  vehicle class total claim amount
# 0                          0  Personal Auto     499.200000       Two-Door Car
# 1                          0  Personal Auto       3.468912       Two-Door Car
# 2                          0  Personal Auto     393.600000      Four-Door Car
# 3                          0  Personal Auto     699.615192                SUV
# 4                          2  Personal Auto     484.800000                SUV

# %%
Customer_Analysis_Round_1 = pd.concat([file1, file2, file3], axis=0)
Customer_Analysis_Round_1.shape
# Out:
# (12074, 11)

# %%
y = file2.shape
z = file3.shape
x = file1.shape
x, z, y
# Out:
# ((4008, 11), (7070, 11), (996, 11))

# %%
Customer_Analysis_Round_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 1.1+ MB

# %%
Customer_Analysis_Round_1.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class total claim amount
# 0  Four-Door Car            2.70493
# 1  Four-Door Car            1131.46
# 2   Two-Door Car            566.472
# 3            SUV            529.881
# 4  Four-Door Car            17.2693

# %%
Customer_Analysis_Round_1.drop(['education', 'number of open complaints'], axis=1, inplace = True)

# %%
Customer_Analysis_Round_1.head()
# Out:
#   customer          st gender customer lifetime value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    monthly premium auto     policy type  vehicle class total claim amount
# 0                1000.0   Personal Auto  Four-Door Car            2.70493
# 1                  94.0   Personal Auto  Four-Door Car            1131.46
# 2                 108.0   Personal Auto   Two-Door Car            566.472
# 3                 106.0  Corporate Auto            SUV            529.881
# 4                  68.0   Personal Auto  Four-Door Car            17.2693

# %%
# Customer_Analysis_Round_1["customer lifetime value"]=list(map(percen_remover, Customer_Analysis_Round_1["customer lifetime value"]))
Customer_Analysis_Round_1["customer lifetime value"].replace({'%': ''}, regex=True)
Customer_Analysis_Round_1["customer lifetime value"] = Customer_Analysis_Round_1["customer lifetime value"].div(100).round(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-26bf1378574c> in <module>
#       1 # Customer_Analysis_Round_1["customer lifetime value"]=list(map(percen_remover, Customer_Analysis_Round_1["customer lifetime value"]))
# ----> 2 Customer_Analysis_Round_1["customer lifetime value"].replace({'%': ''}, regex=True)
#       3 Customer_Analysis_Round_1["customer lifetime value"] = Customer_Analysis_Round_1["customer lifetime value"].div(100).round(2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4561         method="pad",
#    4562     ):
# -> 4563         return super().replace(
#    4564             to_replace=to_replace,
#    4565             value=value,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6498                 to_replace, value = keys, values
#    6499
# -> 6500             return self.replace(
#    6501                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6502             )
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4561         method="pad",
#    4562     ):
# -> 4563         return super().replace(
#    4564             to_replace=to_replace,
#    4565             value=value,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6541                         )
#    6542                     self._consolidate_inplace()
# -> 6543                     new_data = self._mgr.replace_list(
#    6544                         src_list=to_replace,
#    6545                         dest_list=value,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in comp(s, mask, regex)
#     634
#     635             s = com.maybe_box_datetimelike(s)
# --> 636             return _compare_or_regex_search(values, s, regex, mask)
#     637
#     638         # Calculate the mask once, prior to the call of comp
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _compare_or_regex_search(a, b, regex, mask)
#    1990     if is_datetimelike_v_numeric(a, b) or is_numeric_v_string_like(a, b):
#    1991         # GH#29553 avoid deprecation warnings from numpy
# -> 1992         _check_comparison_types(False, a, b)
#    1993         return False
#    1994
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _check_comparison_types(result, a, b)
#    1969                 type_names[0] = f"ndarray(dtype={a.dtype})"
#    1970
# -> 1971             raise TypeError(
#    1972                 f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1973             )
#
# TypeError: Cannot compare types 'ndarray(dtype=float64)' and 'str'

# %%
Customer_Analysis_Round_1.head(10)
# Out:
#   customer          st gender customer lifetime value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
# 5  OC83172      Oregon      F              825629.78%  62902.0
# 6  XZ87318      Oregon      F              538089.86%  55350.0
# 7  CF85061     Arizona      M              721610.03%      0.0
# 8  DY87989      Oregon      M             2412750.40%  14072.0
# 9  BQ94931      Oregon      F              738817.81%  28812.0
#
#    monthly premium auto     policy type  vehicle class total claim amount
# 0                1000.0   Personal Auto  Four-Door Car            2.70493
# 1                  94.0   Personal Auto  Four-Door Car            1131.46
# 2                 108.0   Personal Auto   Two-Door Car            566.472
# 3                 106.0  Corporate Auto            SUV            529.881
# 4                  68.0   Personal Auto  Four-Door Car            17.2693
# 5                  69.0   Personal Auto   Two-Door Car            159.383
# 6                  67.0  Corporate Auto  Four-Door Car              321.6
# 7                 101.0  Corporate Auto  Four-Door Car             363.03
# 8                  71.0  Corporate Auto  Four-Door Car              511.2
# 9                  93.0    Special Auto  Four-Door Car            425.528

# %%
Customer_Analysis_Round_1['customer lifetime value']=pd.to_numeric(Customer_Analysis_Round_1["customer lifetime value"], errors="coerce")

# %%
Customer_Analysis_Round_1['customer lifetime value']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 7065   NaN
# 7066   NaN
# 7067   NaN
# 7068   NaN
# 7069   NaN
# Name: customer lifetime value, Length: 12074, dtype: float64

# %%
Customer_Analysis_Round_1 = Customer_Analysis_Round_1.drop_duplicates()

# %%
Customer_Analysis_Round_1[Customer_Analysis_Round_1['income']>0]
# Out:
#      customer          st   gender  customer lifetime value   income  \
# 2     AI49188      Nevada        F                      NaN  48767.0
# 4     GA49547  Washington        M                      NaN  36357.0
# 5     OC83172      Oregon        F                      NaN  62902.0
# 6     XZ87318      Oregon        F                      NaN  55350.0
# 8     DY87989      Oregon        M                      NaN  14072.0
# ...       ...         ...      ...                      ...      ...
# 7063  TF56202  California  5032.17                      NaN  66367.0
# 7064  YM19146  California   4100.4                      NaN  47761.0
# 7065  LA72316  California    23406                      NaN  71941.0
# 7066  PK87824  California  3096.51                      NaN  21604.0
# 7068  UP19263  California  7524.44                      NaN  21941.0
#
#       monthly premium auto     policy type  vehicle class total claim amount
# 2                    108.0   Personal Auto   Two-Door Car            566.472
# 4                     68.0   Personal Auto  Four-Door Car            17.2693
# 5                     69.0   Personal Auto   Two-Door Car            159.383
# 6                     67.0  Corporate Auto  Four-Door Car              321.6
# 8                     71.0  Corporate Auto  Four-Door Car              511.2
# ...                    ...             ...            ...                ...
# 7063                  64.0   Personal Auto          307.2       Two-Door Car
# 7064                 104.0   Personal Auto        541.282      Four-Door Car
# 7065                  73.0   Personal Auto        198.235      Four-Door Car
# 7066                  79.0  Corporate Auto          379.2      Four-Door Car
# 7068                  96.0   Personal Auto          691.2      Four-Door Car
#
# [6843 rows x 9 columns]
